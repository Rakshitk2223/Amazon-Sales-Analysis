# %%
import pandas as pd
import numpy as np

# %%
path="D:/Amazon Sales Analysis/amazon.csv"
print(path)
# Out:
# D:/Amazon Sales Analysis/amazon.csv

# %%
df=pd.read_csv(path)

# %%
print(f"The number of rows are {df.shape[0]}, and the number of columns is {df.shape[1]}")
# Out:
# The number of rows are 1465, and the number of columns is 16

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
# Import additional libraries for comprehensive analysis
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from datetime import datetime
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Set up plotting style
plt.style.use('default')
sns.set_palette("husl")
warnings.filterwarnings('ignore')

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
df.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%      4       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
# 1. BASIC DATA INFORMATION
print("="*60)
print("AMAZON SALES DATASET - INITIAL ANALYSIS")
print("="*60)
print(f"Dataset Shape: {df.shape}")
print(f"Memory Usage: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")
print("\nColumn Information:")
print("-"*40)
df.info()
# Out:
# ============================================================
# AMAZON SALES DATASET - INITIAL ANALYSIS
# ============================================================
# Dataset Shape: (1465, 16)
# Memory Usage: 8.65 MB
#
# Column Information:
# ----------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
#  15  product_link         1465 non-null   object
# dtypes: object(16)
# memory usage: 183.3+ KB

# %%
# 2. MISSING VALUES AND DUPLICATES ANALYSIS
print("\n" + "="*60)
print("MISSING VALUES ANALYSIS")
print("="*60)
missing_values = df.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100

missing_df = pd.DataFrame({
    'Column': missing_values.index,
    'Missing Count': missing_values.values,
    'Missing Percentage': missing_percentage.values
}).sort_values('Missing Count', ascending=False)

print(missing_df[missing_df['Missing Count'] >0])

print(f"\nDuplicate Rows: {df.duplicated().sum()}")
print(f"Unique Products: {df['product_id'].nunique()}")
print(f"Unique Users: {df['user_id'].nunique()}")
print(f"Unique Reviews: {df['review_id'].nunique()}")
# Out:
# ============================================================
# MISSING VALUES ANALYSIS
# ============================================================
#          Column  Missing Count  Missing Percentage
# 7  rating_count              2            0.136519
#
# Duplicate Rows: 0
# Unique Products: 1351
# Unique Users: 1194
# Unique Reviews: 1194

# %%
# 3. DATA EXAMINATION AND TYPE CONVERSION
print("\n" + "="*60)
print("DATA EXAMINATION")
print("="*60)

# First examine the data formats
print("Sample data from key columns:")
print("Discounted Price samples:", df['discounted_price'].head())
print("Actual Price samples:", df['actual_price'].head())
print("Discount Percentage samples:", df['discount_percentage'].head())
print("Rating samples:", df['rating'].head())
print("Rating Count samples:", df['rating_count'].head())

# Check for any problematic values
print("\nUnique values in rating column:", df['rating'].unique()[:10])
print("Unique values in discount_percentage:", df['discount_percentage'].unique()[:10])
# Out:
# ============================================================
# DATA EXAMINATION
# ============================================================
# Sample data from key columns:
# Discounted Price samples: 0    ₹399
# 1    ₹199
# 2    ₹199
# 3    ₹329
# 4    ₹154
# Name: discounted_price, dtype: object
# Actual Price samples: 0    ₹1,099
# 1      ₹349
# 2    ₹1,899
# 3      ₹699
# 4      ₹399
# Name: actual_price, dtype: object
# Discount Percentage samples: 0    64%
# 1    43%
# 2    90%
# 3    53%
# 4    61%
# Name: discount_percentage, dtype: object
# Rating samples: 0    4.2
# 1      4
# 2    3.9
# 3    4.2
# 4    4.2
# Name: rating, dtype: object
# Rating Count samples: 0    24,269
# 1    43,994
# 2     7,928
# 3    94,363
# 4    16,905
# Name: rating_count, dtype: object
#
# Unique values in rating column: ['4.2' '4' '3.9' '4.1' '4.3' '4.4' '4.5' '3.7' '3.3' '3.6']
# Unique values in discount_percentage: ['64%' '43%' '90%' '53%' '61%' '85%' '65%' '23%' '50%' '33%']

# %%
# 4. CATEGORICAL DATA ANALYSIS
print("\n" + "="*60)
print("CATEGORICAL DATA ANALYSIS")
print("="*60)

categorical_cols = df.select_dtypes(include=['object']).columns
print("Categorical Columns:", list(categorical_cols))

print(f"\nTop 10 Categories:")
print(df['category'].value_counts().head(10))

print(f"\nTop 10 Most Reviewed Products:")
top_products = df.groupby('product_name')['rating_count'].apply(
    lambda x: pd.to_numeric(x.astype(str).str.replace(',', ''), errors='coerce').sum()
).sort_values(ascending=False).head(10)
print(top_products)
# Out:
# ============================================================
# CATEGORICAL DATA ANALYSIS
# ============================================================
# Categorical Columns: ['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count', 'about_product', 'user_id', 'user_name', 'review_id', 'review_title', 'review_content', 'img_link', 'product_link']
#
# Top 10 Categories:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                        233
# Electronics|WearableTechnology|SmartWatches                                                               76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                      68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                             63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                              52
# Electronics|HomeTheater,TV&Video|Accessories|RemoteControls                                               49
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|MixerGrinders                                  27
# Computers&Accessories|Accessories&Peripherals|Keyboards,Mice&InputDevices|Mice                            24
# Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables                                            24
# Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cleaning&Ironing|Irons,Steamers&Accessories|Irons|DryIrons     24
# Name: count, dtype: int64
#
# Top 10 Most Reviewed Products:
# product_name
# AmazonBasics Flexible Premium HDMI Cable (Black, 4K@60Hz, 18Gbps), 3-Foot                                                                  853945.0
# Amazon Basics High-Speed HDMI Cable, 6 Feet - Supports Ethernet, 3D, 4K video,Black                                                        426973.0
# Amazon Basics High-Speed HDMI Cable, 6 Feet (2-Pack),Black                                                                                 426973.0
# JBL C100SI Wired In Ear Headphones with Mic, JBL Pure Bass Sound, One Button Multi-function Remote, Angled Buds for Comfort fit (Black)    385177.0
# boAt Bassheads 100 in Ear Wired Earphones with Mic(Taffy Pink)                                                                             363713.0
# boAt Bassheads 100 in Ear Wired Earphones with Mic(Furious Red)                                                                            363713.0
# boAt BassHeads 100 in-Ear Wired Headphones with Mic (Black)                                                                                363711.0
# Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery                                313836.0
# Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Storage) | Octa-core Helio G35 | 5000 mAh Battery                                               313836.0
# Redmi 9A Sport (Coral Green, 3GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery                                313832.0
# Name: rating_count, dtype: float64
# product_name
# AmazonBasics Flexible Premium HDMI Cable (Black, 4K@60Hz, 18Gbps), 3-Foot                                                                  853945.0
# Amazon Basics High-Speed HDMI Cable, 6 Feet - Supports Ethernet, 3D, 4K video,Black                                                        426973.0
# Amazon Basics High-Speed HDMI Cable, 6 Feet (2-Pack),Black                                                                                 426973.0
# JBL C100SI Wired In Ear Headphones with Mic, JBL Pure Bass Sound, One Button Multi-function Remote, Angled Buds for Comfort fit (Black)    385177.0
# boAt Bassheads 100 in Ear Wired Earphones with Mic(Taffy Pink)                                                                             363713.0
# boAt Bassheads 100 in Ear Wired Earphones with Mic(Furious Red)                                                                            363713.0
# boAt BassHeads 100 in-Ear Wired Headphones with Mic (Black)                                                                                363711.0
# Redmi 9A Sport (Coral Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery                                313836.0
# Redmi 9 Activ (Carbon Black, 4GB RAM, 64GB Storage) | Octa-core Helio G35 | 5000 mAh Battery                                               313836.0
# Redmi 9A Sport (Coral Green, 3GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery                                313832.0
# Name: rating_count, dtype: float64

# %%
# 5. COMPREHENSIVE DATA ANALYSIS WITH PROPER CONVERSION
print("\n" + "="*60)
print("COMPREHENSIVE DATA ANALYSIS")
print("="*60)

# Clean and convert price columns
df['discounted_price_clean'] = pd.to_numeric(df['discounted_price'].str.replace('₹', '').str.replace(',', ''), errors='coerce')
df['actual_price_clean'] = pd.to_numeric(df['actual_price'].str.replace('₹', '').str.replace(',', ''), errors='coerce')
df['discount_percentage_clean'] = pd.to_numeric(df['discount_percentage'].str.replace('%', ''), errors='coerce')

# Clean rating data - handle the "|" issue
df['rating_clean'] = pd.to_numeric(df['rating'].astype(str).str.split('|').str[0], errors='coerce')

# Clean rating count - remove commas and convert to numeric
df['rating_count_clean'] = pd.to_numeric(df['rating_count'].astype(str).str.replace(',', ''), errors='coerce')

print("PRICE ANALYSIS:")
print("-" * 30)
print(f"Average Discounted Price: ₹{df['discounted_price_clean'].mean():.2f}")
print(f"Median Discounted Price: ₹{df['discounted_price_clean'].median():.2f}")
print(f"Average Actual Price: ₹{df['actual_price_clean'].mean():.2f}")
print(f"Median Actual Price: ₹{df['actual_price_clean'].median():.2f}")
print(f"Average Discount: {df['discount_percentage_clean'].mean():.2f}%")
print(f"Max Discount: {df['discount_percentage_clean'].max():.0f}%")

print(f"\nRATING ANALYSIS:")
print("-" * 30)
print(f"Average Rating: {df['rating_clean'].mean():.2f}")
print(f"Median Rating: {df['rating_clean'].median():.2f}")
print(f"Rating Range: {df['rating_clean'].min():.1f} - {df['rating_clean'].max():.1f}")
print(f"Average Rating Count: {df['rating_count_clean'].mean():.0f}")
print(f"Median Rating Count: {df['rating_count_clean'].median():.0f}")

print(f"\nTOP 5 CATEGORIES BY PRODUCT COUNT:")
print("-" * 40)
top_categories = df['category'].value_counts().head(5)
for idx, (category, count) in enumerate(top_categories.items(), 1):
    print(f"{idx}. {category.split('|')[-1]}: {count} products")

print(f"\nPRICE RANGES:")
print("-" * 20)
price_ranges = pd.cut(df['discounted_price_clean'], bins=5, precision=0)
print(price_ranges.value_counts().sort_index())
# Out:
# ============================================================
# COMPREHENSIVE DATA ANALYSIS
# ============================================================
# PRICE ANALYSIS:
# ------------------------------
# Average Discounted Price: ₹3125.31
# Median Discounted Price: ₹799.00
# Average Actual Price: ₹5444.99
# Median Actual Price: ₹1650.00
# Average Discount: 47.69%
# Max Discount: 94%
#
# RATING ANALYSIS:
# ------------------------------
# Average Rating: 4.10
# Median Rating: 4.10
# Rating Range: 2.0 - 5.0
# Average Rating Count: 18296
# Median Rating Count: 5179
#
# TOP 5 CATEGORIES BY PRODUCT COUNT:
# ----------------------------------------
# 1. USBCables: 233 products
# 2. SmartWatches: 76 products
# 3. Smartphones: 68 products
# 4. SmartTelevisions: 63 products
# 5. In-Ear: 52 products
#
# PRICE RANGES:
# --------------------
# discounted_price_clean
# (-39.0, 15629.0]      1394
# (15629.0, 31219.0]      48
# (31219.0, 46810.0]      17
# (46810.0, 62400.0]       5
# (62400.0, 77990.0]       1
# Name: count, dtype: int64

# %%
# 6. INITIAL VISUALIZATIONS
print("\n" + "="*60)
print("CREATING INITIAL VISUALIZATIONS")
print("="*60)

# Create a figure with multiple subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Amazon Sales Dataset - Initial Analysis', fontsize=16, fontweight='bold')

# 1. Price Distribution
axes[0, 0].hist(df['discounted_price_clean'], bins=30, color='skyblue', alpha=0.7, edgecolor='black')
axes[0, 0].set_title('Distribution of Discounted Prices')
axes[0, 0].set_xlabel('Price (₹)')
axes[0, 0].set_ylabel('Frequency')
axes[0, 0].ticklabel_format(style='plain', axis='x')

# 2. Rating Distribution
rating_counts = df['rating_clean'].value_counts().sort_index()
axes[0, 1].bar(rating_counts.index, rating_counts.values, color='lightgreen', alpha=0.7, edgecolor='black')
axes[0, 1].set_title('Distribution of Ratings')
axes[0, 1].set_xlabel('Rating')
axes[0, 1].set_ylabel('Count')

# 3. Discount Percentage Distribution
axes[1, 0].hist(df['discount_percentage_clean'], bins=20, color='coral', alpha=0.7, edgecolor='black')
axes[1, 0].set_title('Distribution of Discount Percentages')
axes[1, 0].set_xlabel('Discount (%)')
axes[1, 0].set_ylabel('Frequency')

# 4. Top 10 Categories
top_cats = df['category'].str.split('|').str[-1].value_counts().head(10)
axes[1, 1].barh(range(len(top_cats)), top_cats.values, color='gold', alpha=0.7, edgecolor='black')
axes[1, 1].set_yticks(range(len(top_cats)))
axes[1, 1].set_yticklabels(top_cats.index, fontsize=8)
axes[1, 1].set_title('Top 10 Product Categories')
axes[1, 1].set_xlabel('Count')

plt.tight_layout()
plt.show()

# Summary statistics table
print("\nSUMMARY STATISTICS TABLE:")
print("=" * 50)
summary_stats = pd.DataFrame({
    'Metric': ['Total Products', 'Total Reviews', 'Avg Rating', 'Avg Discount %', 
               'Avg Discounted Price', 'Most Popular Category', 'Price Range'],
    'Value': [
        f"{df.shape[0]:,}",
        f"{df['rating_count_clean'].sum():,.0f}",
        f"{df['rating_clean'].mean():.2f}",
        f"{df['discount_percentage_clean'].mean():.1f}%",
        f"₹{df['discounted_price_clean'].mean():,.2f}",
        df['category'].str.split('|').str[-1].value_counts().index[0],
        f"₹{df['discounted_price_clean'].min():.0f} - ₹{df['discounted_price_clean'].max():,.0f}"
    ]
})
print(summary_stats.to_string(index=False))
# Out:
# ============================================================
# CREATING INITIAL VISUALIZATIONS
# ============================================================
# SUMMARY STATISTICS TABLE:
# ==================================================
#                Metric         Value
#        Total Products         1,465
#         Total Reviews    26,766,377
#            Avg Rating          4.10
#        Avg Discount %         47.7%
#  Avg Discounted Price     ₹3,125.31
# Most Popular Category     USBCables
#           Price Range ₹39 - ₹77,990

# %%
# 7. MISSING VALUE HANDLING
print("\n" + "="*60)
print("MISSING VALUE HANDLING")
print("="*60)

# Create a copy of the dataframe for cleaning
df_clean = df.copy()

# Handle missing values based on data type
print("Handling missing values...")

# For numerical columns - use mean
numerical_cols = ['discounted_price_clean', 'actual_price_clean', 'discount_percentage_clean', 'rating_clean', 'rating_count_clean']
for col in numerical_cols:
    if df_clean[col].isnull().sum() > 0:
        mean_value = df_clean[col].mean()
        df_clean[col].fillna(mean_value, inplace=True)
        print(f"Filled {col} missing values with mean: {mean_value:.2f}")

# For categorical columns - use mode
categorical_cols = ['category', 'product_name', 'about_product', 'user_name', 'review_title', 'review_content']
for col in categorical_cols:
    if df_clean[col].isnull().sum() > 0:
        mode_value = df_clean[col].mode()[0] if not df_clean[col].mode().empty else 'Unknown'
        df_clean[col].fillna(mode_value, inplace=True)
        print(f"Filled {col} missing values with mode: {mode_value}")

# Verify no missing values remain
print(f"\nMissing values after cleaning:")
missing_after = df_clean.isnull().sum()
print(missing_after[missing_after > 0])
if missing_after.sum() == 0:
    print("✅ All missing values have been handled successfully!")
# Out:
# ============================================================
# MISSING VALUE HANDLING
# ============================================================
# Handling missing values...
# Filled rating_clean missing values with mean: 4.10
# Filled rating_count_clean missing values with mean: 18295.54
#
# Missing values after cleaning:
# rating_count    2
# dtype: int64

# %%
# 8. OUTLIER DETECTION AND ANALYSIS (Improved)
print("\n" + "="*60)
print("OUTLIER DETECTION AND ANALYSIS (Filtered for Valid Values)")
print("="*60)

# Filter out invalid (negative or zero) values before outlier detection
filtered_df = df_clean[
    (df_clean['discounted_price_clean'] > 0) &
    (df_clean['actual_price_clean'] > 0) &
    (df_clean['rating_count_clean'] >= 0)
]

def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers, lower_bound, upper_bound

outlier_columns = ['discounted_price_clean', 'actual_price_clean', 'rating_count_clean']

print("Outlier Analysis (after filtering invalid values):")
print("-" * 30)

for col in outlier_columns:
    outliers, lower, upper = detect_outliers_iqr(filtered_df, col)
    print(f"\n{col}:")
    print(f"  Lower bound: {lower:.2f}")
    print(f"  Upper bound: {upper:.2f}")
    print(f"  Number of outliers: {len(outliers)} ({len(outliers)/len(filtered_df)*100:.2f}%)")
    if len(outliers) > 0:
        print(f"  Outlier range: {outliers[col].min():.2f} to {outliers[col].max():.2f}")

# Improved boxplots (filtered data, y-limit capped for readability)
fig, axes = plt.subplots(1, 3, figsize=(18, 6))
fig.suptitle('Outlier Detection - Box Plots (Filtered)', fontsize=16, fontweight='bold')

for i, col in enumerate(outlier_columns):
    axes[i].boxplot(filtered_df[col].dropna(), patch_artist=True, 
                   boxprops=dict(facecolor='lightblue', alpha=0.7))
    axes[i].set_title(f'{col.replace("_clean", "").replace("_", " ").title()}')
    axes[i].set_ylabel('Value')
    axes[i].tick_params(axis='x', which='both', bottom=False, labelbottom=False)
    # Optionally cap y-axis for better visualization (adjust as needed)
    q99 = filtered_df[col].quantile(0.99)
    axes[i].set_ylim([0, q99 * 1.1])

plt.tight_layout()
plt.show()

print("\n💡 Note: Outliers are now calculated after removing invalid (negative/zero) values. Boxplots are capped at 99th percentile for clarity.")
# Out:
# ============================================================
# OUTLIER DETECTION AND ANALYSIS (Filtered for Valid Values)
# ============================================================
# Outlier Analysis (after filtering invalid values):
# ------------------------------
#
# discounted_price_clean:
#   Lower bound: -2186.00
#   Upper bound: 4510.00
#   Number of outliers: 217 (14.81%)
#   Outlier range: 4699.00 to 77990.00
#
# actual_price_clean:
#   Lower bound: -4442.50
#   Upper bound: 9537.50
#   Number of outliers: 213 (14.54%)
#   Outlier range: 9625.00 to 139900.00
#
# rating_count_clean:
#   Lower bound: -23113.50
#   Upper bound: 41698.50
#   Number of outliers: 141 (9.62%)
#   Outlier range: 42139.00 to 426973.00
# 💡 Note: Outliers are now calculated after removing invalid (negative/zero) values. Boxplots are capped at 99th percentile for clarity.

# %%
 # 8A. DETAILED DATA INVESTIGATION - Understanding Outlier Issues
print("\n" + "="*60)
print("DETAILED DATA INVESTIGATION - OUTLIER ANALYSIS")
print("="*60)

# Let's examine the data distribution more carefully
print("INVESTIGATING DATA DISTRIBUTION:")
print("-" * 40)

# Check basic statistics for each column
cols_to_check = ['discounted_price_clean', 'actual_price_clean', 'rating_count_clean']

for col in cols_to_check:
    print(f"\n{col.upper()}:")
    print(f"  Count: {df_clean[col].count()}")
    print(f"  Mean: {df_clean[col].mean():.2f}")
    print(f"  Median: {df_clean[col].median():.2f}")
    print(f"  Min: {df_clean[col].min():.2f}")
    print(f"  Max: {df_clean[col].max():.2f}")
    print(f"  Std: {df_clean[col].std():.2f}")
    print(f"  25th percentile: {df_clean[col].quantile(0.25):.2f}")
    print(f"  75th percentile: {df_clean[col].quantile(0.75):.2f}")
    print(f"  IQR: {df_clean[col].quantile(0.75) - df_clean[col].quantile(0.25):.2f}")
    
    # Check for negative values
    negative_count = (df_clean[col] < 0).sum()
    zero_count = (df_clean[col] == 0).sum()
    print(f"  Negative values: {negative_count}")
    print(f"  Zero values: {zero_count}")

print(f"\nDATA QUALITY ISSUES:")
print("-" * 30)

# Check for data quality issues
print("Sample of potentially problematic records:")
problematic = df_clean[
    (df_clean['discounted_price_clean'] <= 0) | 
    (df_clean['actual_price_clean'] <= 0) |
    (df_clean['rating_count_clean'] < 0)
]
if len(problematic) > 0:
    print(f"Found {len(problematic)} problematic records:")
    print(problematic[['product_name', 'discounted_price_clean', 'actual_price_clean', 'rating_count_clean']].head())
else:
    print("No problematic records found (negative/zero prices)")

# Check for extreme values
print(f"\nEXTREME VALUES ANALYSIS:")
print("-" * 30)
for col in cols_to_check:
    q99 = df_clean[col].quantile(0.99)
    q95 = df_clean[col].quantile(0.95)
    extreme_count = (df_clean[col] > q99).sum()
    print(f"{col}:")
    print(f"  95th percentile: {q95:.2f}")
    print(f"  99th percentile: {q99:.2f}")
    print(f"  Values above 99th percentile: {extreme_count}")
    if extreme_count > 0:
        extreme_vals = df_clean[df_clean[col] > q99][col].sort_values(ascending=False).head(5)
        print(f"  Top 5 extreme values: {extreme_vals.tolist()}")
    print()
# Out:
# ============================================================
# DETAILED DATA INVESTIGATION - OUTLIER ANALYSIS
# ============================================================
# INVESTIGATING DATA DISTRIBUTION:
# ----------------------------------------
#
# DISCOUNTED_PRICE_CLEAN:
#   Count: 1465
#   Mean: 3125.31
#   Median: 799.00
#   Min: 39.00
#   Max: 77990.00
#   Std: 6944.30
#   25th percentile: 325.00
#   75th percentile: 1999.00
#   IQR: 1674.00
#   Negative values: 0
#   Zero values: 0
#
# ACTUAL_PRICE_CLEAN:
#   Count: 1465
#   Mean: 5444.99
#   Median: 1650.00
#   Min: 39.00
#   Max: 139900.00
#   Std: 10874.83
#   25th percentile: 800.00
#   75th percentile: 4295.00
#   IQR: 3495.00
#   Negative values: 0
#   Zero values: 0
#
# RATING_COUNT_CLEAN:
#   Count: 1465
#   Mean: 18295.54
#   Median: 5179.00
#   Min: 2.00
#   Max: 426973.00
#   Std: 42724.65
#   25th percentile: 1191.00
#   75th percentile: 17394.00
#   IQR: 16203.00
#   Negative values: 0
#   Zero values: 0
#
# DATA QUALITY ISSUES:
# ------------------------------
# Sample of potentially problematic records:
# No problematic records found (negative/zero prices)
#
# EXTREME VALUES ANALYSIS:
# ------------------------------
# discounted_price_clean:
#   95th percentile: 15499.00
#   99th percentile: 34359.00
#   Values above 99th percentile: 15
#   Top 5 extreme values: [77990.0, 61999.0, 54990.0, 47990.0, 47990.0]
#
# actual_price_clean:
#   95th percentile: 24962.00
#   99th percentile: 57906.00
#   Values above 99th percentile: 15
#   Top 5 extreme values: [139900.0, 85000.0, 79990.0, 75990.0, 74999.0]
#
# rating_count_clean:
#   95th percentile: 74976.80
#   99th percentile: 197076.32
#   Values above 99th percentile: 15
#   Top 5 extreme values: [426973.0, 426973.0, 426973.0, 426972.0, 363713.0]

# %%
# 8B. IMPROVED OUTLIER DETECTION WITH PROPER DATA FILTERING
print("\n" + "="*60)
print("IMPROVED OUTLIER DETECTION")
print("="*60)

# Create a properly filtered dataset (remove invalid values)
print("Filtering data for valid values only...")
valid_df = df_clean[
    (df_clean['discounted_price_clean'] > 0) &
    (df_clean['actual_price_clean'] > 0) &
    (df_clean['rating_count_clean'] >= 0) &
    (df_clean['discounted_price_clean'].notna()) &
    (df_clean['actual_price_clean'].notna()) &
    (df_clean['rating_count_clean'].notna())
].copy()

print(f"Original dataset: {len(df_clean)} records")
print(f"Valid dataset: {len(valid_df)} records")
print(f"Removed {len(df_clean) - len(valid_df)} invalid records")

# Improved outlier detection function
def detect_outliers_improved(data, column, method='iqr'):
    """Detect outliers using IQR method with proper bounds"""
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    
    # Standard IQR method
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # For price data, ensure lower bound is not negative
    if 'price' in column.lower():
        lower_bound = max(0, lower_bound)
    
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers, lower_bound, upper_bound, Q1, Q3, IQR

# Analyze outliers in valid data
outlier_columns = ['discounted_price_clean', 'actual_price_clean', 'rating_count_clean']

print(f"\nOUTLIER ANALYSIS (Valid Data Only):")
print("-" * 40)

outlier_summary = {}
for col in outlier_columns:
    outliers, lower, upper, q1, q3, iqr = detect_outliers_improved(valid_df, col)
    
    outlier_summary[col] = {
        'count': len(outliers),
        'percentage': len(outliers)/len(valid_df)*100,
        'lower_bound': lower,
        'upper_bound': upper
    }
    
    print(f"\n{col}:")
    print(f"  Q1: {q1:.2f}")
    print(f"  Q3: {q3:.2f}")
    print(f"  IQR: {iqr:.2f}")
    print(f"  Lower bound: {lower:.2f}")
    print(f"  Upper bound: {upper:.2f}")
    print(f"  Outliers: {len(outliers)} ({len(outliers)/len(valid_df)*100:.2f}%)")
    
    if len(outliers) > 0:
        print(f"  Outlier range: {outliers[col].min():.2f} to {outliers[col].max():.2f}")
        # Show some example outlier products
        print(f"  Sample outlier products:")
        sample_outliers = outliers.nlargest(3, col)
        for idx, row in sample_outliers.iterrows():
            print(f"    • {row['product_name'][:50]}... = {row[col]:.0f}")

# Create improved visualizations
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('Improved Outlier Analysis - Valid Data Only', fontsize=16, fontweight='bold')

# Box plots for each column
for i, col in enumerate(outlier_columns):
    # Box plot (capped at 95th percentile for better visualization)
    q95 = valid_df[col].quantile(0.95)
    axes[0, i].boxplot(valid_df[col].clip(upper=q95), patch_artist=True, 
                      boxprops=dict(facecolor='lightblue', alpha=0.7))
    axes[0, i].set_title(f'{col.replace("_clean", "").replace("_", " ").title()}\n(Capped at 95th percentile)')
    axes[0, i].set_ylabel('Value')
    axes[0, i].tick_params(axis='x', which='both', bottom=False, labelbottom=False)
    
    # Histogram with outlier threshold lines
    axes[1, i].hist(valid_df[col], bins=50, alpha=0.7, color='skyblue', edgecolor='black')
    
    # Add outlier threshold lines
    _, lower, upper, _, _, _ = detect_outliers_improved(valid_df, col)
    axes[1, i].axvline(upper, color='red', linestyle='--', alpha=0.8, label=f'Upper bound: {upper:.0f}')
    if lower > 0:
        axes[1, i].axvline(lower, color='red', linestyle='--', alpha=0.8, label=f'Lower bound: {lower:.0f}')
    
    axes[1, i].set_title(f'Distribution with Outlier Bounds')
    axes[1, i].set_xlabel('Value')
    axes[1, i].set_ylabel('Frequency')
    axes[1, i].legend()
    
    # Set reasonable x-axis limits for better visualization
    axes[1, i].set_xlim(0, valid_df[col].quantile(0.95) * 1.1)

plt.tight_layout()
plt.show()

print(f"\nOUTLIER EXPLANATION:")
print("=" * 30)
print("• The negative lower bounds in the original analysis were due to the IQR method")
print("• This happens when Q1 - 1.5*IQR < 0, which is common in right-skewed data")
print("• Many outliers are legitimate: premium products, viral products, etc.")
print("• For prices, we've adjusted lower bounds to be non-negative")
print("• The high number of outliers indicates the data is heavily right-skewed")
print("• This is typical for e-commerce data with luxury/premium items")
# Out:
# ============================================================
# IMPROVED OUTLIER DETECTION
# ============================================================
# Filtering data for valid values only...
# Original dataset: 1465 records
# Valid dataset: 1465 records
# Removed 0 invalid records
#
# OUTLIER ANALYSIS (Valid Data Only):
# ----------------------------------------
#
# discounted_price_clean:
#   Q1: 325.00
#   Q3: 1999.00
#   IQR: 1674.00
#   Lower bound: 0.00
#   Upper bound: 4510.00
#   Outliers: 217 (14.81%)
#   Outlier range: 4699.00 to 77990.00
#   Sample outlier products:
#     • Sony Bravia 164 cm (65 inches) 4K Ultra HD Smart L... = 77990
#     • OnePlus 163.8 cm (65 inches) U Series 4K LED Smart... = 61999
#     • VU 164 cm (65 inches) The GloLED Series 4K Smart L... = 54990
#
# actual_price_clean:
#   Q1: 800.00
#   Q3: 4295.00
#   IQR: 3495.00
#   Lower bound: 0.00
#   Upper bound: 9537.50
#   Outliers: 213 (14.54%)
#   Outlier range: 9625.00 to 139900.00
#   Sample outlier products:
#     • Sony Bravia 164 cm (65 inches) 4K Ultra HD Smart L... = 139900
#     • VU 164 cm (65 inches) The GloLED Series 4K Smart L... = 85000
#     • LG 139 cm (55 inches) 4K Ultra HD Smart LED TV 55U... = 79990
#
# rating_count_clean:
#   Q1: 1191.00
#   Q3: 17394.00
#   IQR: 16203.00
#   Lower bound: -23113.50
#   Upper bound: 41698.50
#   Outliers: 141 (9.62%)
#   Outlier range: 42139.00 to 426973.00
#   Sample outlier products:
#     • AmazonBasics Flexible Premium HDMI Cable (Black, 4... = 426973
#     • Amazon Basics High-Speed HDMI Cable, 6 Feet - Supp... = 426973
#     • Amazon Basics High-Speed HDMI Cable, 6 Feet (2-Pac... = 426973
# OUTLIER EXPLANATION:
# ==============================
# • The negative lower bounds in the original analysis were due to the IQR method
# • This happens when Q1 - 1.5*IQR < 0, which is common in right-skewed data
# • Many outliers are legitimate: premium products, viral products, etc.
# • For prices, we've adjusted lower bounds to be non-negative
# • The high number of outliers indicates the data is heavily right-skewed
# • This is typical for e-commerce data with luxury/premium items

# %%
# 9. PAIR PLOTS AND CORRELATION ANALYSIS
print("\n" + "="*60)
print("PAIR PLOTS AND CORRELATION ANALYSIS")
print("="*60)

# Select key numerical variables for pair plot
pair_plot_cols = ['discounted_price_clean', 'actual_price_clean', 'discount_percentage_clean', 'rating_clean', 'rating_count_clean']

# Create a subset for pair plot (sample if dataset is large)
if len(df_clean) > 1000:
    df_sample = df_clean[pair_plot_cols].sample(n=1000, random_state=42)
    print("Using sample of 1000 records for pair plot due to dataset size...")
else:
    df_sample = df_clean[pair_plot_cols]

# Create pair plot
print("Creating pair plot...")
plt.figure(figsize=(15, 12))
pair_plot = sns.pairplot(df_sample, diag_kind='hist', plot_kws={'alpha': 0.6})
pair_plot.fig.suptitle('Pair Plot - Key Numerical Variables', fontsize=16, y=1.02)
plt.show()

# Correlation heatmap
print("\nCorrelation Analysis:")
print("-" * 30)
correlation_matrix = df_clean[pair_plot_cols].corr()
print(correlation_matrix.round(3))

# Visualize correlation matrix
plt.figure(figsize=(10, 8))
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
sns.heatmap(correlation_matrix, mask=mask, annot=True, cmap='coolwarm', center=0,
            square=True, fmt='.3f', cbar_kws={"shrink": .8})
plt.title('Correlation Heatmap - Key Variables', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# Key correlations
print("\nKey Correlations:")
print("-" * 20)
significant_corr = correlation_matrix.abs() > 0.3
for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        if significant_corr.iloc[i, j]:
            col1 = correlation_matrix.columns[i]
            col2 = correlation_matrix.columns[j]
            corr_val = correlation_matrix.iloc[i, j]
            print(f"{col1} ↔ {col2}: {corr_val:.3f}")
# Out:
# ============================================================
# PAIR PLOTS AND CORRELATION ANALYSIS
# ============================================================
# Using sample of 1000 records for pair plot due to dataset size...
# Creating pair plot...
# Correlation Analysis:
# ------------------------------
#                            discounted_price_clean  actual_price_clean  \
# discounted_price_clean                      1.000               0.962
# actual_price_clean                          0.962               1.000
# discount_percentage_clean                  -0.242              -0.118
# rating_clean                                0.120               0.122
# rating_count_clean                         -0.027              -0.036
#
#                            discount_percentage_clean  rating_clean  \
# discounted_price_clean                        -0.242         0.120
# actual_price_clean                            -0.118         0.122
# discount_percentage_clean                      1.000        -0.155
# rating_clean                                  -0.155         1.000
# rating_count_clean                             0.012         0.101
#
#                            rating_count_clean
# discounted_price_clean                 -0.027
# actual_price_clean                     -0.036
# discount_percentage_clean               0.012
# rating_clean                            0.101
# rating_count_clean                      1.000
# Key Correlations:
# --------------------
# discounted_price_clean ↔ actual_price_clean: 0.962

# %%
# 10. SPECIFIC ANALYSIS - MAX DISCOUNT, PRICE, AND REVIEWS
print("\n" + "="*60)
print("SPECIFIC ANALYSIS - MAXIMUMS")
print("="*60)

# Create figure with subplots for specific analysis
fig, axes = plt.subplots(2, 2, figsize=(16, 12))
fig.suptitle('Amazon Sales - Maximum Values Analysis', fontsize=16, fontweight='bold')

# 1. Products with Maximum Discounts
max_discount_products = df_clean.nlargest(10, 'discount_percentage_clean')
axes[0, 0].barh(range(len(max_discount_products)), max_discount_products['discount_percentage_clean'], 
                color='red', alpha=0.7)
axes[0, 0].set_yticks(range(len(max_discount_products)))
axes[0, 0].set_yticklabels([name[:30] + '...' if len(name) > 30 else name 
                           for name in max_discount_products['product_name']], fontsize=8)
axes[0, 0].set_title('Top 10 Products by Discount %')
axes[0, 0].set_xlabel('Discount Percentage (%)')

# 2. Most Expensive Products
max_price_products = df_clean.nlargest(10, 'actual_price_clean')
axes[0, 1].barh(range(len(max_price_products)), max_price_products['actual_price_clean'], 
                color='green', alpha=0.7)
axes[0, 1].set_yticks(range(len(max_price_products)))
axes[0, 1].set_yticklabels([name[:30] + '...' if len(name) > 30 else name 
                           for name in max_price_products['product_name']], fontsize=8)
axes[0, 1].set_title('Top 10 Most Expensive Products')
axes[0, 1].set_xlabel('Actual Price (₹)')

# 3. Products with Most Reviews
max_review_products = df_clean.nlargest(10, 'rating_count_clean')
axes[1, 0].barh(range(len(max_review_products)), max_review_products['rating_count_clean'], 
                color='blue', alpha=0.7)
axes[1, 0].set_yticks(range(len(max_review_products)))
axes[1, 0].set_yticklabels([name[:30] + '...' if len(name) > 30 else name 
                           for name in max_review_products['product_name']], fontsize=8)
axes[1, 0].set_title('Top 10 Most Reviewed Products')
axes[1, 0].set_xlabel('Number of Reviews')

# 4. Highest Rated Products (with minimum 100 reviews for credibility)
high_rated_products = df_clean[df_clean['rating_count_clean'] >= 100].nlargest(10, 'rating_clean')
axes[1, 1].barh(range(len(high_rated_products)), high_rated_products['rating_clean'], 
                color='orange', alpha=0.7)
axes[1, 1].set_yticks(range(len(high_rated_products)))
axes[1, 1].set_yticklabels([name[:30] + '...' if len(name) > 30 else name 
                           for name in high_rated_products['product_name']], fontsize=8)
axes[1, 1].set_title('Top 10 Highest Rated Products (100+ reviews)')
axes[1, 1].set_xlabel('Rating')

plt.tight_layout()
plt.show()

# Print detailed information about maximum values
print("\nMAXIMUM VALUES SUMMARY:")
print("=" * 40)

print(f"\n🔥 MAXIMUM DISCOUNT:")
max_discount_product = df_clean.loc[df_clean['discount_percentage_clean'].idxmax()]
print(f"Product: {max_discount_product['product_name'][:60]}")
print(f"Discount: {max_discount_product['discount_percentage_clean']:.0f}%")
print(f"Original Price: ₹{max_discount_product['actual_price_clean']:,.0f}")
print(f"Discounted Price: ₹{max_discount_product['discounted_price_clean']:,.0f}")

print(f"\n💰 MOST EXPENSIVE PRODUCT:")
max_price_product = df_clean.loc[df_clean['actual_price_clean'].idxmax()]
print(f"Product: {max_price_product['product_name'][:60]}")
print(f"Price: ₹{max_price_product['actual_price_clean']:,.0f}")
print(f"Rating: {max_price_product['rating_clean']:.1f}/5.0")
print(f"Reviews: {max_price_product['rating_count_clean']:,.0f}")

print(f"\n⭐ MOST REVIEWED PRODUCT:")
max_review_product = df_clean.loc[df_clean['rating_count_clean'].idxmax()]
print(f"Product: {max_review_product['product_name'][:60]}")
print(f"Reviews: {max_review_product['rating_count_clean']:,.0f}")
print(f"Rating: {max_review_product['rating_clean']:.1f}/5.0")
print(f"Price: ₹{max_review_product['discounted_price_clean']:,.0f}")

print(f"\n🏆 HIGHEST RATED PRODUCT (with 100+ reviews):")
if len(high_rated_products) > 0:
    top_rated = high_rated_products.iloc[0]
    print(f"Product: {top_rated['product_name'][:60]}")
    print(f"Rating: {top_rated['rating_clean']:.1f}/5.0")
    print(f"Reviews: {top_rated['rating_count_clean']:,.0f}")
    print(f"Price: ₹{top_rated['discounted_price_clean']:,.0f}")
# Out:
# ============================================================
# SPECIFIC ANALYSIS - MAXIMUMS
# ============================================================
# MAXIMUM VALUES SUMMARY:
# ========================================
#
# 🔥 MAXIMUM DISCOUNT:
# Product: rts [2 Pack] Mini USB C Type C Adapter Plug, Type C Female t
# Discount: 94%
# Original Price: ₹4,999
# Discounted Price: ₹294
#
# 💰 MOST EXPENSIVE PRODUCT:
# Product: Sony Bravia 164 cm (65 inches) 4K Ultra HD Smart LED Google
# Price: ₹139,900
# Rating: 4.7/5.0
# Reviews: 5,935
#
# ⭐ MOST REVIEWED PRODUCT:
# Product: AmazonBasics Flexible Premium HDMI Cable (Black, 4K@60Hz, 18
# Reviews: 426,973
# Rating: 4.4/5.0
# Price: ₹219
#
# 🏆 HIGHEST RATED PRODUCT (with 100+ reviews):
# Product: REDTECH USB-C to Lightning Cable 3.3FT, [Apple MFi Certified
# Rating: 5.0/5.0
# Reviews: 18,296
# Price: ₹249

# %%
# 11. CREATE CLEAN DATASET FOR TABLEAU
print("\n" + "="*60)
print("CREATING CLEAN DATASET FOR TABLEAU")
print("="*60)

# Create a new clean dataframe with essential columns for Tableau analysis
tableau_df = pd.DataFrame()

# Essential columns for dashboard
tableau_df['Product_ID'] = df_clean['product_id']
tableau_df['Product_Name'] = df_clean['product_name']

# Extract main category and subcategory
tableau_df['Main_Category'] = df_clean['category'].str.split('|').str[0]
tableau_df['Sub_Category'] = df_clean['category'].str.split('|').str[-1]
tableau_df['Full_Category'] = df_clean['category']

# Clean price columns
tableau_df['Discounted_Price'] = df_clean['discounted_price_clean']
tableau_df['Actual_Price'] = df_clean['actual_price_clean']
tableau_df['Discount_Percentage'] = df_clean['discount_percentage_clean']
tableau_df['Savings_Amount'] = df_clean['actual_price_clean'] - df_clean['discounted_price_clean']

# Rating information
tableau_df['Rating'] = df_clean['rating_clean']
tableau_df['Rating_Count'] = df_clean['rating_count_clean']

# Create derived metrics for analysis
tableau_df['Price_Range'] = pd.cut(tableau_df['Discounted_Price'], 
                                  bins=[0, 500, 1000, 2500, 5000, float('inf')], 
                                  labels=['Under ₹500', '₹500-1000', '₹1000-2500', '₹2500-5000', 'Above ₹5000'])

tableau_df['Rating_Category'] = pd.cut(tableau_df['Rating'], 
                                      bins=[0, 3.0, 3.5, 4.0, 4.5, 5.0], 
                                      labels=['Poor (≤3.0)', 'Fair (3.0-3.5)', 'Good (3.5-4.0)', 'Very Good (4.0-4.5)', 'Excellent (4.5-5.0)'])

tableau_df['Discount_Category'] = pd.cut(tableau_df['Discount_Percentage'], 
                                        bins=[0, 25, 50, 75, 100], 
                                        labels=['Low (0-25%)', 'Medium (25-50%)', 'High (50-75%)', 'Very High (75%+)'])

tableau_df['Review_Volume'] = pd.cut(tableau_df['Rating_Count'], 
                                    bins=[0, 100, 1000, 10000, float('inf')], 
                                    labels=['Low (<100)', 'Medium (100-1K)', 'High (1K-10K)', 'Very High (10K+)'])

# Add user and review information (limited)
tableau_df['User_ID'] = df_clean['user_id']
tableau_df['User_Name'] = df_clean['user_name']
tableau_df['Review_Title'] = df_clean['review_title']

# Clean up any remaining missing values
tableau_df = tableau_df.fillna({
    'Product_Name': 'Unknown Product',
    'Main_Category': 'Unknown',
    'Sub_Category': 'Unknown',
    'User_Name': 'Anonymous'
})

# Display dataset information
print(f"Clean Dataset Shape: {tableau_df.shape}")
print(f"Columns: {list(tableau_df.columns)}")

print(f"\nDataset Summary:")
print("-" * 30)
print(f"Total Products: {tableau_df['Product_ID'].nunique():,}")
print(f"Total Categories: {tableau_df['Main_Category'].nunique()}")
print(f"Total Sub-categories: {tableau_df['Sub_Category'].nunique()}")
print(f"Average Price: ₹{tableau_df['Discounted_Price'].mean():,.2f}")
print(f"Average Rating: {tableau_df['Rating'].mean():.2f}")
print(f"Total Users: {tableau_df['User_ID'].nunique():,}")

# Check for any remaining missing values
missing_check = tableau_df.isnull().sum()
if missing_check.sum() > 0:
    print(f"\nRemaining missing values:")
    print(missing_check[missing_check > 0])
else:
    print("\n✅ No missing values in clean dataset!")

# Display sample data
print(f"\nSample of Clean Dataset:")
print(tableau_df.head())

# Export to CSV for Tableau
output_path = "D:/Amazon Sales Analysis/CleanedAmazonSales.csv"
tableau_df.to_csv(output_path, index=False)
print(f"\n✅ Clean dataset exported to: {output_path}")
print(f"📊 Ready for Tableau import!")

print(f"\nFILE SUMMARY:")
print("=" * 20)
print(f"Original dataset: {df.shape[0]:,} rows × {df.shape[1]} columns")
print(f"Cleaned dataset: {tableau_df.shape[0]:,} rows × {tableau_df.shape[1]} columns")
print(f"Size reduction: {(1 - tableau_df.shape[1]/df.shape[1])*100:.1f}% fewer columns")
print(f"File saved as: CleanedAmazonSales.csv")
# Out:
# ============================================================
# CREATING CLEAN DATASET FOR TABLEAU
# ============================================================
# Clean Dataset Shape: (1465, 18)
# Columns: ['Product_ID', 'Product_Name', 'Main_Category', 'Sub_Category', 'Full_Category', 'Discounted_Price', 'Actual_Price', 'Discount_Percentage', 'Savings_Amount', 'Rating', 'Rating_Count', 'Price_Range', 'Rating_Category', 'Discount_Category', 'Review_Volume', 'User_ID', 'User_Name', 'Review_Title']
#
# Dataset Summary:
# ------------------------------
# Total Products: 1,351
# Total Categories: 9
# Total Sub-categories: 207
# Average Price: ₹3,125.31
# Average Rating: 4.10
# Total Users: 1,194
#
# Remaining missing values:
# Discount_Category    49
# dtype: int64
#
# Sample of Clean Dataset:
#    Product_ID                                       Product_Name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#            Main_Category Sub_Category  \
# 0  Computers&Accessories    USBCables
# 1  Computers&Accessories    USBCables
# 2  Computers&Accessories    USBCables
# 3  Computers&Accessories    USBCables
# 4  Computers&Accessories    USBCables
#
#                                        Full_Category  Discounted_Price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    Actual_Price  Discount_Percentage  Savings_Amount  Rating  Rating_Count  \
# 0        1099.0                   64           700.0     4.2       24269.0
# 1         349.0                   43           150.0     4.0       43994.0
# 2        1899.0                   90          1700.0     3.9        7928.0
# 3         699.0                   53           370.0     4.2       94363.0
# 4         399.0                   61           245.0     4.2       16905.0
#
#   Price_Range      Rating_Category Discount_Category     Review_Volume  \
# 0  Under ₹500  Very Good (4.0-4.5)     High (50-75%)  Very High (10K+)
# 1  Under ₹500       Good (3.5-4.0)   Medium (25-50%)  Very High (10K+)
# 2  Under ₹500       Good (3.5-4.0)  Very High (75%+)     High (1K-10K)
# 3  Under ₹500  Very Good (4.0-4.5)     High (50-75%)  Very High (10K+)
# 4  Under ₹500  Very Good (4.0-4.5)     High (50-75%)  Very High (10K+)
#
#                                              User_ID  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            User_Name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                         Review_Title
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
# ✅ Clean dataset exported to: D:/Amazon Sales Analysis/CleanedAmazonSales.csv
# 📊 Ready for Tableau import!
#
# FILE SUMMARY:
# ====================
# Original dataset: 1,465 rows × 24 columns
# Cleaned dataset: 1,465 rows × 18 columns
# Size reduction: 25.0% fewer columns
# File saved as: CleanedAmazonSales.csv
